# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

housing = fetch_california_housing()
df=pd.DataFrame(data=housing.data,columns=housing.feature_names)
df[housing.target_names[0]]=housing.target

# %% [markdown]
# # Transformacion logaritmica
# Compensa sesgo positivo
# $$
# X'=\log(X).
# $$

# %%
h=df.hist(bins=50,figsize=(8,5))
plt.tight_layout()

# %%
df.skew()
# Out:
# MedInc          1.646657
# HouseAge        0.060331
# AveRooms       20.697869
# AveBedrms      31.316956
# Population      4.935858
# AveOccup       97.639561
# Latitude        0.465953
# Longitude      -0.297801
# MedHouseVal     0.977763
# dtype: float64

# %%
df.AveOccup.max()
# Out:
# 1243.3333333333333

# %%
# Grafica X vs X'
X=np.linspace(0.1,10,100)
Xp=np.log10(X)
plt.plot(X,Xp)
plt.plot(X,X-1,'--k')
plt.grid()

# %%
df_t=df.copy()
df_t=np.log10(df-df.min()+1)
df.skew(),df_t.skew()
# Out:
# (MedInc          1.646657
#  HouseAge        0.060331
#  AveRooms       20.697869
#  AveBedrms      31.316956
#  Population      4.935858
#  AveOccup       97.639561
#  Latitude        0.465953
#  Longitude      -0.297801
#  MedHouseVal     0.977763
#  dtype: float64,
#  MedInc         0.078282
#  HouseAge      -1.289170
#  AveRooms       0.959245
#  AveBedrms      8.298256
#  Population    -1.140433
#  AveOccup       2.662098
#  Latitude      -0.080214
#  Longitude     -0.745362
#  MedHouseVal    0.237146
#  dtype: float64)

# %%
df_t.hist(bins=50,figsize=(10,7))
plt.tight_layout()

# %% [markdown]
# # Transformación recíproca
# Compensa sesgo positivo muy pronunciado
# $$
# X'=\frac{1}{X}.
# $$

# %%
# Comparación entre log y recíproco
plt.plot(X,Xp+1,label='Logarítmo')
plt.plot(X,1/X,label='Recíproco')
plt.plot(X,X,'--k')
plt.legend()
plt.grid()

# %%
df_r=df.copy()
df_r=1/(df-df.min()+1)
df.skew(),df_r.skew()
# Out:
# (MedInc          1.646657
#  HouseAge        0.060331
#  AveRooms       20.697869
#  AveBedrms      31.316956
#  Population      4.935858
#  AveOccup       97.639561
#  Latitude        0.465953
#  Longitude      -0.297801
#  MedHouseVal     0.977763
#  dtype: float64,
#  MedInc          1.329928
#  HouseAge        5.719626
#  AveRooms        1.864921
#  AveBedrms      -3.911728
#  Population     80.838678
#  AveOccup        0.612341
#  Latitude        1.097306
#  Longitude       2.185543
#  MedHouseVal     0.507905
#  dtype: float64)

# %%
df_r.hist(bins=50,figsize=(10,7))
plt.tight_layout()

# %%
dft,dfr=df_t.skew().values,df_r.skew().values
np.abs(dft),np.abs(dfr)
# Out:
# (array([0.07828239, 1.28916984, 0.95924537, 8.29825562, 1.1404329 ,
#         2.66209805, 0.08021368, 0.74536241, 0.2371457 ]),
#  array([ 1.32992848,  5.71962582,  1.86492071,  3.9117278 , 80.83867774,
#          0.61234061,  1.09730581,  2.18554341,  0.50790523]))

# %%
for transformacion in zip(np.abs(dft),np.abs(dfr)):
    print(np.argmin(transformacion))
# Out:
# 0
# 0
# 0
# 1
# 0
# 1
# 0
# 0
# 0

# %%
df_t=df.copy()
for var in range(len(df.columns)):
    x=df.iloc[:,var]
    if var in (3,5):
        df_t.iloc[:,var]=1/(x-x.min()+1)
    else:
        df_t.iloc[:,var]=np.log10(x-x.min()+1)
df_t.skew()
# Out:
# MedInc         0.078282
# HouseAge      -1.289170
# AveRooms       0.959245
# AveBedrms     -3.911728
# Population    -1.140433
# AveOccup       0.612341
# Latitude      -0.080214
# Longitude     -0.745362
# MedHouseVal    0.237146
# dtype: float64

# %%
from sklearn import linear_model
Xt,xt,Yt,yt=train_test_split(df_t.drop(columns='MedHouseVal'),df_t['MedHouseVal'])
lin=LinearRegression()
lin.fit(Xt,Yt)
# Out:
# LinearRegression()

# %%
lin.score(Xt,Yt),lin.score(xt,yt)
# Out:
# (0.6275134953416541, 0.6181925707128706)

# %%
df_t.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       0.604400      1.400658      0.728738      0.576377      3.049293
# std        0.176024      0.246570      0.115886      0.048713      0.322996
# min        0.000000      0.000000      0.000000      0.028791      0.000000
# 25%        0.486218      1.255273      0.662244      0.566190      2.894870
# 50%        0.605833      1.462398      0.731022      0.582938      3.065953
# 75%        0.719609      1.568202      0.792828      0.597819      3.236285
# max        1.190337      1.716003      2.152481      1.000000      4.552425
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       0.325632      0.548797      0.730180      0.433816
# std        0.074101      0.239255      0.175392      0.163272
# min        0.000804      0.000000      0.000000      0.000000
# 25%        0.278555      0.378398      0.550228      0.310908
# 50%        0.319917      0.434569      0.836324      0.422756
# 75%        0.365306      0.790285      0.865696      0.543728
# max        1.000000      1.017451      1.042969      0.767157

# %%
plt.scatter(df_t['AveBedrms'],lin.predict(df_t.drop(columns='MedHouseVal')),label='predicción',s=5)
plt.scatter(df_t['AveBedrms'],df_t['MedHouseVal'],label='Observaciones',s=5)
plt.legend()
plt.grid()

# %%
X,x,Y,y=train_test_split(df.drop(columns='MedHouseVal'),df['MedHouseVal'])
lin=LinearRegression()
lin.fit(X,Y)
# Out:
# LinearRegression()

# %%
lin.score(X,Y),lin.score(x,y)
# Out:
# (0.614559371626165, 0.5760469877199283)

# %%
plt.scatter(df['AveBedrms'],df['MedHouseVal'],label='Observaciones',s=5)
plt.scatter(df['AveBedrms'],lin.predict(df.drop(columns='MedHouseVal')),label='Predicción',s=5)
plt.legend(loc=1)
plt.grid()

# %%
df=pd.read_csv('regresion.csv')
df.head()
# Out:
#           x         y
# 0  0.100000  1.932916
# 1  0.101001  2.242087
# 2  0.102002  2.022414
# 3  0.103003  1.692315
# 4  0.104004  1.672025

# %%
plt.scatter(df['x'],df['y'],s=5)
plt.grid()

# %%
df['y'].skew()
# Out:
# 0.6089606600475832

# %%
np.log(df['y']-df['y'].min()+1).skew(),(1/(df['y']-df['y'].min()+1)).skew()
# Out:
# (-0.15922700879254476, 1.0805166141039333)

# %%
df_t=df.copy()
df_t['y']=np.log(df['y']-df['y'].min()+1)
df_t.hist()
# Out:
# array([[<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'y'}>]], dtype=object)

# %%
plt.scatter(df_t['x'],df_t['y'],s=5)
plt.grid()

# %%
lint=LinearRegression()
Xt,xt,Yt,yt=train_test_split(df_t[['x']],df_t['y'])
lint.fit(Xt,Yt)
lint.score(Xt,Yt),lint.score(xt,yt)
# Out:
# (0.8065783116855172, 0.8019518077090608)

# %%
lin=LinearRegression()
X,x,Y,y=train_test_split(df[['x']],df['y'])
lin.fit(X,Y)
lin.score(X,Y),lin.score(x,y)
# Out:
# (0.7943404341307362, 0.7614038635576306)

# %%
plt.scatter(df_t['x'],df_t['y'],s=5)
plt.plot(df_t['x'],lint.predict(df_t[['x']]),'r')
plt.grid()

# %%
plt.scatter(df['x'],df['y'],s=5)
prediccion=lint.predict(df[['x']])
y=np.exp(prediccion)+df['y'].min()-1
plt.plot(df['x'],y,'r')
plt.grid()
